# %%
import os 
import sys
import cv2
import csv
import pickle
import argparse
import collections
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def get_lines(annotations):
    '''
    extract the image file names and their corridor lines position
    Input:
        annotations - pandas data frame
    Output:
        lines_loc - dict object, contains the two lines coordinates [x1, x2, y1, y2]
    '''
    
    lines_loc = collections.defaultdict(list)

    N = len(annotations)
    for i in range(N):
        f = annotations.iloc[i, 0]
        assert annotations.iloc[i, 3] == 2

        lines = annotations.iloc[i, 5]
        xpoints = lines.split('[')[1].split(']')[0].split(',')
        ypoints = lines.split('[')[2].split(']')[0].split(',')

        xpoints = [int(item) for item in xpoints]
        ypoints = [int(item) for item in ypoints]

        lines_loc[f].append(xpoints + ypoints)

    return lines_loc

def format_labels(lines_loc):
    '''
    reformat label to vanishing point location and two slopes
    Input:
        lines_loc - dict object, contains the two lines coordinates [x1, x2, y1, y2]
    Output:
        labels - 
    '''
    labels = collections.defaultdict(list)
    for fname in lines_loc.keys():
        x1, x2, y1, y2 = lines_loc[fname][0]
        x3, x4, y3, y4 = lines_loc[fname][1]
        # compute intersection point
        x = ((x1*y2-x2*y1)*(x3-x4) - (x3*y4-x4*y3)*(x1-x2)) / ((x1-x2)*(y3-y4) - (y1-y2)*(x3-x4))
        y = ((x1*y2-x2*y1)*(y3-y4) - (x3*y4-x4*y3)*(y1-y2)) / ((x1-x2)*(y3-y4) - (y1-y2)*(x3-x4))
        # compute two slopes
        theta1 = np.rad2deg(np.arctan2(y2-y1, x2-x1))
        theta2 = np.rad2deg(np.arctan2(y4-y3, x4-x3))

        labels[fname] = [x, y, theta1, theta2]

    return labels

def draw_corridor(img, label):
    '''
    draw vanishing point and two lines
    Input:
        img - RGB image
        label - [x1, y1, theta1, theta2]
    Output:
        image - 
    '''
    vpz = label[:2]
    img = cv2.circle(img, (int(vpz[0]), int(vpz[1])), 3, (0, 255, 255), 3)
    return img

# %%
img_dir = './corn_front_data/color/'
annotation_csv = 'corn_front_data/via_annotations.csv'
output_dir = os.path.join('corn_front_data', 'labeled_img')
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

csv_path = os.path.join('corn_front_data', 'dataset.csv')
result_csv = csv.writer(open(csv_path, 'w'), delimiter=',')

stride = 25
win_size = 100

annotations = pd.read_csv(annotation_csv)
lines_loc = get_lines(annotations)
labels = format_labels(lines_loc)

# %%
idx = 0
fname = list(labels.keys())[0]
img = cv2.imread(os.path.join(img_dir, fname))
lines = lines_loc[fname]
x1, x2, y1, y2 = lines[0]
x3, x4, y3, y4 = lines[1]
print('[%d %d] [%d %d],  [%d %d] [%d %d]'%(x1, y1, x2, y2, x3, y3, x4, y4))
cv2.line(img, (x1, y1), (x2, y2), (255, 0, 0), 3)
cv2.line(img, (x3, y3), (x4, y4), (255, 0, 0), 3)
plt.imshow(img)
# Out:
# [164 464] [472 192],  [738 448] [360 193]

# %%
label = labels[fname]
print(label)
vpzx, vpzy = int(label[0]), int(label[1])
img = cv2.circle(img, (vpzx, vpzy), 3, (0, 255, 255), 3)
plt.imshow(img)
# Out:
# [422.85409911996294, 235.4015748031496, -41.4482666451796, -145.99627258088745]

# %%
theta1, theta2 = np.deg2rad(label[2]), np.deg2rad(label[3])

l = 200
# find pt1
dx = l * np.cos(theta1)
dy = l * np.sin(theta1)
if dy < 0:
    dx, dy = -dx, -dy
pt1 = (int(vpzx+dx), int(vpzy+dy))

# find pt2
dx = l * np.cos(theta1)
dy = l * np.sin(theta1)
if dy < 0:
    dx, dy = -dx, -dy
pt1 = (int(vpzx+dx), int(vpzy+dy))

img = cv2.line(img, (vpzx, vpzy), (pt1[0], pt1[1]), (0,0,255), 2)


plt.imshow(img)

# %% [markdown]
# # test model shape

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
from torchsummary import summary

class CorridorNet(nn.Module):
    def __init__(self):
        super(CorridorNet, self).__init__()

        resnet = models.resnet18(pretrained=True)
        self.resnet_backbone = nn.Sequential(*(list(resnet.children())[:-2]))

        self.predictor = nn.Sequential(
                nn.Conv2d(512, 512, 5, 2),
                nn.ReLU(),
                nn.Conv2d(512, 512, 5, 2),
                nn.ReLU()
            )
        self.fc = nn.Sequential(
                nn.Linear(2048, 256),
                nn.ReLU(),
                nn.Linear(256, 4)
        )
        
    def forward(self, x):
        # ft = self.resnet(x)
        # out = self.predictor(ft)
        # return out
        out = self.resnet_backbone(x)
        out = self.predictor(out)
        out = torch.flatten(out, 1)
        out = self.fc(out)
        return out
    

m = CorridorNet().cuda()
summary(m, (3, 480, 848))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 240, 424]           9,408
#        BatchNorm2d-2         [-1, 64, 240, 424]             128
#               ReLU-3         [-1, 64, 240, 424]               0
#          MaxPool2d-4         [-1, 64, 120, 212]               0
#             Conv2d-5         [-1, 64, 120, 212]          36,864
#        BatchNorm2d-6         [-1, 64, 120, 212]             128
#               ReLU-7         [-1, 64, 120, 212]               0
#             Conv2d-8         [-1, 64, 120, 212]          36,864
#        BatchNorm2d-9         [-1, 64, 120, 212]             128
#              ReLU-10         [-1, 64, 120, 212]               0
#        BasicBlock-11         [-1, 64, 120, 212]               0
#            Conv2d-12         [-1, 64, 120, 212]          36,864
#       BatchNorm2d-13         [-1, 64, 120, 212]             128
#              ReLU-14         [-1, 64, 120, 212]               0
#            Conv2d-15         [-1, 64, 120, 212]          36,864
#       BatchNorm2d-16         [-1, 64, 120, 212]             128
#              ReLU-17         [-1, 64, 120, 212]               0
#        BasicBlock-18         [-1, 64, 120, 212]               0
#            Conv2d-19         [-1, 128, 60, 106]          73,728
#       BatchNorm2d-20         [-1, 128, 60, 106]             256
#              ReLU-21         [-1, 128, 60, 106]               0
#            Conv2d-22         [-1, 128, 60, 106]         147,456
#       BatchNorm2d-23         [-1, 128, 60, 106]             256
#            Conv2d-24         [-1, 128, 60, 106]           8,192
#       BatchNorm2d-25         [-1, 128, 60, 106]             256
#              ReLU-26         [-1, 128, 60, 106]               0
#        BasicBlock-27         [-1, 128, 60, 106]               0
#            Conv2d-28         [-1, 128, 60, 106]         147,456
#       BatchNorm2d-29         [-1, 128, 60, 106]             256
#              ReLU-30         [-1, 128, 60, 106]               0
#            Conv2d-31         [-1, 128, 60, 106]         147,456
#       BatchNorm2d-32         [-1, 128, 60, 106]             256
#              ReLU-33         [-1, 128, 60, 106]               0
#        BasicBlock-34         [-1, 128, 60, 106]               0
#            Conv2d-35          [-1, 256, 30, 53]         294,912
#       BatchNorm2d-36          [-1, 256, 30, 53]             512
#              ReLU-37          [-1, 256, 30, 53]               0
#            Conv2d-38          [-1, 256, 30, 53]         589,824
#       BatchNorm2d-39          [-1, 256, 30, 53]             512
#            Conv2d-40          [-1, 256, 30, 53]          32,768
#       BatchNorm2d-41          [-1, 256, 30, 53]             512
#              ReLU-42          [-1, 256, 30, 53]               0
#        BasicBlock-43          [-1, 256, 30, 53]               0
#            Conv2d-44          [-1, 256, 30, 53]         589,824
#       BatchNorm2d-45          [-1, 256, 30, 53]             512
#              ReLU-46          [-1, 256, 30, 53]               0
#            Conv2d-47          [-1, 256, 30, 53]         589,824
#       BatchNorm2d-48          [-1, 256, 30, 53]             512
#              ReLU-49          [-1, 256, 30, 53]               0
#        BasicBlock-50          [-1, 256, 30, 53]               0
#            Conv2d-51          [-1, 512, 15, 27]       1,179,648
#       BatchNorm2d-52          [-1, 512, 15, 27]           1,024
#              ReLU-53          [-1, 512, 15, 27]               0
#            Conv2d-54          [-1, 512, 15, 27]       2,359,296
#       BatchNorm2d-55          [-1, 512, 15, 27]           1,024
#            Conv2d-56          [-1, 512, 15, 27]         131,072
#       BatchNorm2d-57          [-1, 512, 15, 27]           1,024
#              ReLU-58          [-1, 512, 15, 27]               0
#        BasicBlock-59          [-1, 512, 15, 27]               0
#            Conv2d-60          [-1, 512, 15, 27]       2,359,296
#       BatchNorm2d-61          [-1, 512, 15, 27]           1,024
#              ReLU-62          [-1, 512, 15, 27]               0
#            Conv2d-63          [-1, 512, 15, 27]       2,359,296
#       BatchNorm2d-64          [-1, 512, 15, 27]           1,024
#              ReLU-65          [-1, 512, 15, 27]               0
#        BasicBlock-66          [-1, 512, 15, 27]               0
#            Conv2d-67           [-1, 512, 6, 12]       6,554,112
#              ReLU-68           [-1, 512, 6, 12]               0
#            Conv2d-69            [-1, 512, 1, 4]       6,554,112
#              ReLU-70            [-1, 512, 1, 4]               0
#            Linear-71                  [-1, 256]         524,544
#              ReLU-72                  [-1, 256]               0
#            Linear-73                    [-1, 4]           1,028
# ================================================================
# Total params: 24,810,308
# Trainable params: 24,810,308
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 4.66
# Forward/backward pass size (MB): 510.36
# Params size (MB): 94.64
# Estimated Total Size (MB): 609.67
# ----------------------------------------------------------------

# %% [markdown]
# # test color thresholding

# %%
img_1 = cv2.imread('corn_front_data/color/bag2_frame000340.png')
img_2 = cv2.imread('corn_front_data//color/bag1_frame002050.png')

# %%
img_1.dtype
# Out:
# dtype('uint8')
